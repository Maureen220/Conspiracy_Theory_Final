# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy import create_engine
import psycopg2
import config
from config import db_password

# %% [markdown]
# # Loading Table 1 Into Database

# %%
#load in first dataset
government_malfeasance_df = pd.read_csv('Resources/government_malfeasance.csv')
government_malfeasance_df
# Out:
#       government_malfeasance  education  urban  gender  engnat  age  hand  \
# 0                   5.000000          3      0       1       2   28     1
# 1                   4.000000          1      2       2       1   14     1
# 2                   2.000000          4      2       2       2   26     1
# 3                   5.000000          3      1       1       1   25     1
# 4                   5.000000          2      2       1       1   37     1
# ...                      ...        ...    ...     ...     ...  ...   ...
# 2490                4.666667          3      3       1       1   32     1
# 2491                2.000000          4      2       2       2   25     2
# 2492                3.666667          2      3       2       2   34     1
# 2493                1.333333          2      2       1       2   19     1
# 2494                3.666667          1      3       2       2   16     1
#
#       religion  orientation  race  voted  married  familysize
# ...

# %%
government_malfeasance_df['government_malfeasance']=government_malfeasance_df['government_malfeasance'].round(0).astype(int)
government_malfeasance_df
# Out:
#       government_malfeasance  education  urban  gender  engnat  age  hand  \
# 0                          5          3      0       1       2   28     1
# 1                          4          1      2       2       1   14     1
# 2                          2          4      2       2       2   26     1
# 3                          5          3      1       1       1   25     1
# 4                          5          2      2       1       1   37     1
# ...                      ...        ...    ...     ...     ...  ...   ...
# 2490                       5          3      3       1       1   32     1
# 2491                       2          4      2       2       2   25     2
# 2492                       4          2      3       2       2   34     1
# 2493                       1          2      2       1       2   19     1
# 2494                       4          1      3       2       2   16     1
#
#       religion  orientation  race  voted  married  familysize
# ...

# %%
# # Connect to sql database 
# # If you were loading from Jupyter Notebook to SQL, this works. 
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/mock_database_final_project"
engine = create_engine(db_string)
government_malfeasance_df.to_sql(name='government_malfeasance', con=engine, if_exists = 'replace')

# %%
#import table from sql database 
government_malfeasance_DB_df = pd.read_sql_table("government_malfeasance", con=engine, index_col="index")

# %%
government_malfeasance_DB_df
# Out:
#        government_malfeasance  education  urban  gender  engnat  age  hand  \
# index
# 0                           5          3      0       1       2   28     1
# 1                           4          1      2       2       1   14     1
# 2                           2          4      2       2       2   26     1
# 3                           5          3      1       1       1   25     1
# 4                           5          2      2       1       1   37     1
# ...                       ...        ...    ...     ...     ...  ...   ...
# 2490                        5          3      3       1       1   32     1
# 2491                        2          4      2       2       2   25     2
# 2492                        4          2      3       2       2   34     1
# 2493                        1          2      2       1       2   19     1
# 2494                        4          1      3       2       2   16     1
#
# ...

# %% [markdown]
# # Loading Table 2 Into Database

# %%
#load in second dataset
control_of_info_df = pd.read_csv('Resources/control_of_info.csv')
control_of_info_df
# Out:
#       control_of_info  education  urban  gender  engnat  age  hand  religion  \
# 0            5.000000          3      0       1       2   28     1         2
# 1            4.666667          1      2       2       1   14     1         1
# 2            3.333333          4      2       2       2   26     1         1
# 3            4.666667          3      1       1       1   25     1        12
# 4            4.666667          2      2       1       1   37     1         2
# ...               ...        ...    ...     ...     ...  ...   ...       ...
# 2490         4.333333          3      3       1       1   32     1         2
# 2491         1.666667          4      2       2       2   25     2         2
# 2492         3.666667          2      3       2       2   34     1        12
# 2493         2.333333          2      2       1       2   19     1         1
# 2494         3.000000          1      3       2       2   16     1        12
#
# ...

# %%
control_of_info_df['control_of_info']=control_of_info_df['control_of_info'].round(0).astype(int)
control_of_info_df
# Out:
#       control_of_info  education  urban  gender  engnat  age  hand  religion  \
# 0                   5          3      0       1       2   28     1         2
# 1                   5          1      2       2       1   14     1         1
# 2                   3          4      2       2       2   26     1         1
# 3                   5          3      1       1       1   25     1        12
# 4                   5          2      2       1       1   37     1         2
# ...               ...        ...    ...     ...     ...  ...   ...       ...
# 2490                4          3      3       1       1   32     1         2
# 2491                2          4      2       2       2   25     2         2
# 2492                4          2      3       2       2   34     1        12
# 2493                2          2      2       1       2   19     1         1
# 2494                3          1      3       2       2   16     1        12
#
# ...

# %%
# # Connect to sql database 
# # If you were loading from Jupyter Notebook to SQL, this works. 
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/mock_database_final_project"
engine = create_engine(db_string)
control_of_info_df.to_sql(name='control_of_info', con=engine, if_exists = 'replace')

# %%
#import table from sql database 
control_of_info_DB_df = pd.read_sql_table("control_of_info", con=engine, index_col="index")

# %%
control_of_info_DB_df
# Out:
#        control_of_info  education  urban  gender  engnat  age  hand  religion  \
# index
# 0                    5          3      0       1       2   28     1         2
# 1                    5          1      2       2       1   14     1         1
# 2                    3          4      2       2       2   26     1         1
# 3                    5          3      1       1       1   25     1        12
# 4                    5          2      2       1       1   37     1         2
# ...                ...        ...    ...     ...     ...  ...   ...       ...
# 2490                 4          3      3       1       1   32     1         2
# 2491                 2          4      2       2       2   25     2         2
# 2492                 4          2      3       2       2   34     1        12
# 2493                 2          2      2       1       2   19     1         1
# 2494                 3          1      3       2       2   16     1        12
#
# ...

# %% [markdown]
# # Loading Table 3 Into Database

# %%
#load in first dataset
et_df = pd.read_csv('Resources/et.csv')
et_df
# Out:
#             et  education  urban  gender  engnat  age  hand  religion  \
# 0     3.000000          3      0       1       2   28     1         2
# 1     4.666667          1      2       2       1   14     1         1
# 2     1.000000          4      2       2       2   26     1         1
# 3     1.000000          3      1       1       1   25     1        12
# 4     2.333333          2      2       1       1   37     1         2
# ...        ...        ...    ...     ...     ...  ...   ...       ...
# 2490  2.000000          3      3       1       1   32     1         2
# 2491  1.000000          4      2       2       2   25     2         2
# 2492  2.333333          2      3       2       2   34     1        12
# 2493  2.666667          2      2       1       2   19     1         1
# 2494  4.000000          1      3       2       2   16     1        12
#
#       orientation  race  voted  married  familysize
# 0               1     5      2        1           1
# ...

# %%
et_df['et']=et_df['et'].round(0).astype(int)
et_df
# Out:
#       et  education  urban  gender  engnat  age  hand  religion  orientation  \
# 0      3          3      0       1       2   28     1         2            1
# 1      5          1      2       2       1   14     1         1            2
# 2      1          4      2       2       2   26     1         1            1
# 3      1          3      1       1       1   25     1        12            1
# 4      2          2      2       1       1   37     1         2            2
# ...   ..        ...    ...     ...     ...  ...   ...       ...          ...
# 2490   2          3      3       1       1   32     1         2            1
# 2491   1          4      2       2       2   25     2         2            1
# 2492   2          2      3       2       2   34     1        12            2
# 2493   3          2      2       1       2   19     1         1            1
# 2494   4          1      3       2       2   16     1        12            3
#
#       race  voted  married  familysize
# ...

# %%
# # Connect to sql database 
# # If you were loading from Jupyter Notebook to SQL, this works. 
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/mock_database_final_project"
engine = create_engine(db_string)
et_df.to_sql(name='et', con=engine, if_exists = 'replace')

# %%
#import table from sql database 
et_DB_df = pd.read_sql_table("et", con=engine, index_col="index")

# %%
et_DB_df
# Out:
#        et  education  urban  gender  engnat  age  hand  religion  orientation  \
# index
# 0       3          3      0       1       2   28     1         2            1
# 1       5          1      2       2       1   14     1         1            2
# 2       1          4      2       2       2   26     1         1            1
# 3       1          3      1       1       1   25     1        12            1
# 4       2          2      2       1       1   37     1         2            2
# ...    ..        ...    ...     ...     ...  ...   ...       ...          ...
# 2490    2          3      3       1       1   32     1         2            1
# 2491    1          4      2       2       2   25     2         2            1
# 2492    2          2      3       2       2   34     1        12            2
# 2493    3          2      2       1       2   19     1         1            1
# 2494    4          1      3       2       2   16     1        12            3
#
# ...

# %% [markdown]
# # Load Table 4 into the Database

# %%
#load in first dataset
global_conspiracies_df = pd.read_csv('Resources/global_conspiracies.csv')
global_conspiracies_df
# Out:
#       global_conspiracies  education  urban  gender  engnat  age  hand  \
# 0                5.000000          3      0       1       2   28     1
# 1                5.000000          1      2       2       1   14     1
# 2                4.000000          4      2       2       2   26     1
# 3                4.333333          3      1       1       1   25     1
# 4                4.333333          2      2       1       1   37     1
# ...                   ...        ...    ...     ...     ...  ...   ...
# 2490             2.666667          3      3       1       1   32     1
# 2491             1.000000          4      2       2       2   25     2
# 2492             5.000000          2      3       2       2   34     1
# 2493             1.000000          2      2       1       2   19     1
# 2494             3.666667          1      3       2       2   16     1
#
#       religion  orientation  race  voted  married  familysize
# ...

# %%
global_conspiracies_df['global_conspiracies']=global_conspiracies_df['global_conspiracies'].round(0).astype(int)
global_conspiracies_df
# Out:
#       global_conspiracies  education  urban  gender  engnat  age  hand  \
# 0                       5          3      0       1       2   28     1
# 1                       5          1      2       2       1   14     1
# 2                       4          4      2       2       2   26     1
# 3                       4          3      1       1       1   25     1
# 4                       4          2      2       1       1   37     1
# ...                   ...        ...    ...     ...     ...  ...   ...
# 2490                    3          3      3       1       1   32     1
# 2491                    1          4      2       2       2   25     2
# 2492                    5          2      3       2       2   34     1
# 2493                    1          2      2       1       2   19     1
# 2494                    4          1      3       2       2   16     1
#
#       religion  orientation  race  voted  married  familysize
# ...

# %%
# # Connect to sql database 
# # If you were loading from Jupyter Notebook to SQL, this works. 
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/mock_database_final_project"
engine = create_engine(db_string)
global_conspiracies_df.to_sql(name='global_conspiracies', con=engine, if_exists = 'replace')

# %%
#import table from sql database 
global_conspiracies_DB_df = pd.read_sql_table("global_conspiracies", con=engine, index_col="index")

# %%
global_conspiracies_DB_df
# Out:
#        global_conspiracies  education  urban  gender  engnat  age  hand  \
# index
# 0                        5          3      0       1       2   28     1
# 1                        5          1      2       2       1   14     1
# 2                        4          4      2       2       2   26     1
# 3                        4          3      1       1       1   25     1
# 4                        4          2      2       1       1   37     1
# ...                    ...        ...    ...     ...     ...  ...   ...
# 2490                     3          3      3       1       1   32     1
# 2491                     1          4      2       2       2   25     2
# 2492                     5          2      3       2       2   34     1
# 2493                     1          2      2       1       2   19     1
# 2494                     4          1      3       2       2   16     1
#
#        religion  orientation  race  voted  married  familysize
# index
# ...

# %% [markdown]
# # Load table 5 into the Database

# %%
#load in first dataset
personal_wellbeing_df = pd.read_csv('Resources/personal_wellbeing.csv')
personal_wellbeing_df
# Out:
#       personal_wellbeing  education  urban  gender  engnat  age  hand  \
# 0               4.666667          3      0       1       2   28     1
# 1               3.333333          1      2       2       1   14     1
# 2               2.000000          4      2       2       2   26     1
# 3               3.333333          3      1       1       1   25     1
# 4               3.333333          2      2       1       1   37     1
# ...                  ...        ...    ...     ...     ...  ...   ...
# 2490            1.666667          3      3       1       1   32     1
# 2491            1.000000          4      2       2       2   25     2
# 2492            4.333333          2      3       2       2   34     1
# 2493            1.000000          2      2       1       2   19     1
# 2494            2.666667          1      3       2       2   16     1
#
#       religion  orientation  race  voted  married  familysize
# 0            2            1     5      2        1           1
# ...

# %%
personal_wellbeing_df['personal_wellbeing']=personal_wellbeing_df['personal_wellbeing'].round(0).astype(int)
personal_wellbeing_df
# Out:
#       personal_wellbeing  education  urban  gender  engnat  age  hand  \
# 0                      5          3      0       1       2   28     1
# 1                      3          1      2       2       1   14     1
# 2                      2          4      2       2       2   26     1
# 3                      3          3      1       1       1   25     1
# 4                      3          2      2       1       1   37     1
# ...                  ...        ...    ...     ...     ...  ...   ...
# 2490                   2          3      3       1       1   32     1
# 2491                   1          4      2       2       2   25     2
# 2492                   4          2      3       2       2   34     1
# 2493                   1          2      2       1       2   19     1
# 2494                   3          1      3       2       2   16     1
#
#       religion  orientation  race  voted  married  familysize
# 0            2            1     5      2        1           1
# ...

# %%
# # Connect to sql database 
# # If you were loading from Jupyter Notebook to SQL, this works. 
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/mock_database_final_project"
engine = create_engine(db_string)
personal_wellbeing_df.to_sql(name='personal_wellbeing', con=engine, if_exists = 'replace')

# %%
#import table from sql database 
personal_wellbeing_DB_df = pd.read_sql_table("personal_wellbeing", con=engine, index_col="index")

# %%
personal_wellbeing_DB_df
# Out:
#        personal_wellbeing  education  urban  gender  engnat  age  hand  \
# index
# 0                       5          3      0       1       2   28     1
# 1                       3          1      2       2       1   14     1
# 2                       2          4      2       2       2   26     1
# 3                       3          3      1       1       1   25     1
# 4                       3          2      2       1       1   37     1
# ...                   ...        ...    ...     ...     ...  ...   ...
# 2490                    2          3      3       1       1   32     1
# 2491                    1          4      2       2       2   25     2
# 2492                    4          2      3       2       2   34     1
# 2493                    1          2      2       1       2   19     1
# 2494                    3          1      3       2       2   16     1
#
#        religion  orientation  race  voted  married  familysize
# index
# ...
